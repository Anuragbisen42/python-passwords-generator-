# %%
import random
char="qwertyuiopasdfghjklzxcvbnmQAWSEDRFTGYHUJIKOLPMNBVCXZ,./;1234567890"
length=int(input("enter the lenth"))
pasword=""
for a in range(length):
    pasword+=random.choice(char)
    print(pasword)
# Out:
# enter the lenth15
# v
# vU
# vUk
# vUkG
# vUkGB
# vUkGBX
# vUkGBX;
# vUkGBX;y
# vUkGBX;yY
# vUkGBX;yYL
# vUkGBX;yYLu
# vUkGBX;yYLuS
# vUkGBX;yYLuSF
# vUkGBX;yYLuSFY
# vUkGBX;yYLuSFYp
